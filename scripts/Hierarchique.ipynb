# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
import preprocessing
import sklearn.metrics
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-d7a805af03d4> in <module>
#       6 import sklearn.metrics
#       7 from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
# ----> 8 import kmeans.ipynb
#
# ModuleNotFoundError: No module named 'kmeans'

# %%
data=pd.read_csv('../src/jain_out.txt')

data.columns=['x','y','classe']
data.drop(['classe'],axis=1)
x=data.iloc[:,0]
y=data.iloc[:,1]
labelsjain=data.iloc[:,2]
plt.xlabel("x")
plt.ylabel("y")
plt.title("Clustering Jain.txt Fournies")
plt.scatter(x,y,c=labelsjain)
plt.show()

# %%
def hierarchique(data,method,metric):
    l=linkage(data,method='complete',metric='euclidean')
    d=dendrogram(l)
    plt.title("Dendrogramme")
    plt.show()
data=pd.read_csv('../src/jain_out.txt')
hierarchique(data,'complete','euclidean')
